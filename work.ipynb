# %%
import sys
print(sys.executable)  # should show C:\Python313\python.exe
# !{sys.executable} -m pip install -U pip pandas ipykernel
import pandas as pd; print(pd.__version__)
# Out:
# c:\Users\Yench\AppData\Local\Programs\Python\Python311\python.exe
# ...
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.3 MB 4.5 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/11.3 MB 5.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.7/11.3 MB 5.6 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.3 MB 6.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.3 MB 6.6 MB/s eta 0:00:02
# ...
